# %% [markdown]
# #Files, exceptional handling, logging and memory management
# #Theory Questions And Ans

# %% [markdown]
# Q1.  What is the difference between interpreted and compiled language?
#
# -  Interpreted languages (like Python, JavaScript) are executed line by line by an interpreter at runtime.
# -  Compiled languages (like C, C++) are translated into machine code by a compiler before execution, so they run faster.
#
# Q2. What is exception handling in Python?
#
# -  Exception handling in Python is a way to deal with runtime errors so the program doesn’t crash. It uses keywords like try, except, else, finally to catch errors and define what should happen when an error occurs.
#
# Q3. What is the purpose of the finally block in exception handling?
#
# - The finally block in Python is used to define code that will always run, no matter what — whether an exception occurs or not.
#
# Q4.  What is logging in Python?
#
# -  Logging in Python is the process of recording messages (like errors, warnings, or info) while a program runs, to help with debugging and monitoring.
#
# It uses the built-in logging module instead of just print(), because logging gives levels (DEBUG, INFO, WARNING, ERROR, CRITICAL) and can save messages to files.
#
# Q5. What is the significance of the __del__ method in Python?
#
# -  The __del__ method in Python is a destructor that is called when an object is about to be destroyed (i.e., when its reference count drops to zero). It’s mainly used for cleanup tasks like closing files or releasing resources, but its use is generally discouraged because object deletion timing is not always predictable (especially with garbage collection).
#
# Q6. What is the difference between import and from ... import in Python?
#
# -  import brings in the whole module and you access functions with the module name (module.func()).
# from ... import brings specific attributes/functions directly, so you can use them without the module prefix.
#
# Q7. How can you handle multiple exceptions in Python?
#
# -  You can handle multiple exceptions by listing them in a single except clause as a tuple, or by writing multiple except blocks. This lets you catch and manage different error types separately or together.
#
# Q8.  What is the purpose of the with statement when handling files in Python?
#
# -  The with statement ensures that a file is properly opened and automatically closed after its block of code is executed, even if errors occur.
#
# Q9. What is the difference between multithreading and multiprocessing?
#
# -  Multithreading runs multiple threads within the same process, sharing memory space.
# -  Multiprocessing runs multiple processes, each with its own memory space, allowing true parallelism.
#
# Q10. What are the advantages of using logging in a program?
#
# -  Advantages of using logging in a program:
#
# 1. Debugging help – Records errors and flow of execution.
# 2. Persistence – Saves logs to files for later analysis.
# 3. Different levels – Supports levels like DEBUG, INFO, WARNING, ERROR, CRITICAL.
# 4. Flexibility – Can log to console, file, or external systems.
# 5. Better than print() – Easier to manage, filter, and disable without changing code.
#
# Q11.  What is memory management in Python?
#
# -  Memory management in Python is the process of allocating and releasing memory automatically for objects. It is handled by the Python Memory Manager and includes:
#
# -  Private heap space where all objects are stored.
# -  Automatic garbage collection using reference counting and the garbage collector to free unused memory.
#
# This ensures efficient use of memory without manual allocation or deallocation.
#
# Q12. What are the basic steps involved in exception handling in Python?
#
# -  The basic steps in exception handling in Python are:
#
# 1. try block – Write code that may raise an exception.
# 2. except block – Catch and handle specific exceptions.
# 3. else block (optional) – Runs if no exception occurs.
# 4. finally block (optional) – Runs always, for cleanup tasks.
#
# Q13.  Why is memory management important in Python?
#
# -  Memory management is important in Python because it:
#
# 1. Prevents memory leaks by freeing unused objects.
# 2. Improves performance through efficient memory allocation.
# 3. Ensures stability so programs don’t crash due to excessive memory use.
# 4. Simplifies coding since developers don’t need manual memory handling.
#
# Q14.  What is the role of try and except in exception handling?
#
# - In exception handling, the try block contains code that might raise an error, and the except block defines how to handle that error if it occurs, preventing the program from crashing.
#
# Q15.  How does Python's garbage collection system work?
#
# -  Python’s garbage collection works mainly in two ways:
#
# 1. Reference Counting – Each object keeps track of how many references point to it. When the count drops to zero, the memory is freed.
# 2. Garbage Collector (GC) – Handles circular references (objects referencing each other) using a cyclic garbage collector, ensuring unused objects are cleaned up.
#
# This automatic system helps manage memory efficiently without manual intervention.
#
# Q16.  What is the purpose of the else block in exception handling?
#
# -  The else block in exception handling runs only if no exception occurs in the try block. Its purpose is to keep the normal execution code separate from error-handling code.
#
# Q17.  What are the common logging levels in Python?
#
# -  The common logging levels in Python are:
#
# 1. DEBUG – Detailed information for debugging.
# 2. INFO – Confirmation that things are working as expected.
# 3. WARNING – Indication of a potential problem.
# 4. ERROR – A serious issue; program can’t perform a function.
# 5. CRITICAL – Severe error; program may crash.
#
# Q18. What is the difference between os.fork() and multiprocessing in Python?
#
# -  os.fork() creates a child process by duplicating the current process (Unix-only). It’s low-level, less portable, and requires manual handling of communication between processes.
#
# multiprocessing is a Python module that provides a high-level, cross-platform API for creating and managing processes, with built-in support for communication, synchronization, and sharing data safely.
#
# Q19. What is the importance of closing a file in Python?
#
# -  Closing a file in Python is important because it:
#
# 1. Frees system resources (like file handles).
# 2. Ensures data is saved properly from buffer to disk.
# 3. Prevents data corruption or file access issues.
# 4. Allows other programs to access the file safely.
#
# Using with handles closing automatically.
#
# Q20.  What is the difference between file.read() and file.readline() in Python?
#
# -  file.read() → Reads the entire file (or a specified number of bytes) into a single string.
# * file.readline() → Reads one line at a time from the file, ending at a newline character.
#
# Q21. What is the logging module in Python used for?
#
# -  The logging module in Python is used for recording messages about a program’s execution. It helps track events, errors, and debugging information with different severity levels, and can log outputs to the console, files, or external systems.
#
# Q22. What is the os module in Python used for in file handling?
#
# -  The os module in Python is used for interacting with the operating system. In file handling, it helps with tasks like:
#
# - Creating, deleting, or renaming files and directories.
# - Checking file/directory existence and properties (os.path).
# - Navigating directories (os.chdir(), os.getcwd()).
# - Managing file paths in a platform-independent way.
#
# Q23. What are the challenges associated with memory management in Python?
#
# -  Challenges with memory management in Python include:
#
# 1. Garbage collection overhead – Automatic cleanup can slow performance.
# 2. Circular references – Objects referencing each other may delay memory release.
# 3. Memory leaks – Caused by lingering references or improper resource handling.
# 4. High memory usage – Python objects take more space than lower-level languages.
# 5. Unpredictable timing – Exact moment of garbage collection isn’t always known.
#
# Q24.  How do you raise an exception manually in Python?
#
# -  Haan, bina code ke bhi short answer diya ja sakta hai:
#
# You manually raise an exception in Python using the raise statement, specifying the type of exception and an optional error message.
#
# Q25. Why is it important to use multithreading in certain applications?
#
# -  Multithreading is important because it allows a program to perform multiple tasks simultaneously, improving responsiveness and efficiency, especially in I/O-bound applications like web servers, file handling, or GUI programs where tasks can run concurrently without waiting for others to finish.

# %% [markdown]
# #Practical Questions And Ans

# %% [markdown]
# Q1.  How can you open a file for writing in Python and write a string to it?

# %%
with open("example.txt", "w") as file:
    file.write("Hello, this is a sample text.")

print

# %% [markdown]
# Q2. Write a Python program to read the contents of a file and print each line.

# %%
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, this is a sample text!

# %% [markdown]
# Q3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    with open("nonexistent.txt", "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print("Error: The file does not exist!")
# Out:
# Error: The file does not exist!

# %% [markdown]
# Q4. Write a Python script that reads from one file and writes its content to another file.

# %%
source_file = "source.txt"
destination_file = "destination.txt"

try:
    with open(source_file, "r") as src, open(destination_file, "w") as dest:
        for line in src:
            dest.write(line)
    print(f"Contents copied from {source_file} to {destination_file}")
except FileNotFoundError:
    print(f"Error: {source_file} does not exist!")
# Out:
# Error: source.txt does not exist!

# %% [markdown]
# Q5.  How would you catch and handle division by zero error in Python?

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
else:
    print("Result:", result)
# Out:
# Error: Cannot divide by zero!

# %% [markdown]
# Q6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging

# Configure logging to write to a file
logging.basicConfig(filename="error.log", level=logging.ERROR,
                    format="%(asctime)s - %(levelname)s - %(message)s")

try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
except ZeroDivisionError as e:
    logging.error("Division by zero occurred: %s", e)
    print("An error occurred. Check 'error.log' for details.")
else:
    print("Result:", result)
# Out:
# ERROR:root:Division by zero occurred: division by zero
# An error occurred. Check 'error.log' for details.

# %% [markdown]
# Q7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging


logging.basicConfig(filename="app.log",
                    level=logging.DEBUG,
                    format="%(asctime)s - %(levelname)s - %(message)s")

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# Q8. Write a program to handle a file opening error using exception handling.

# %%
filename = "example.txt"

try:
    with open(filename, "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist!")
except IOError:
    print(f"Error: Could not read the file '{filename}'")
else:
    print("File read successfully.")
finally:
    print("File handling attempt finished.")
# Out:
# Hello, this is a sample text!
# File read successfully.
# File handling attempt finished.

# %% [markdown]
# Q9. How can you read a file line by line and store its content in a list in Python?

# %%
filename = "example.txt"

try:
    with open(filename, "r") as file:
        lines = [line.strip() for line in file]  # Remove newline characters
    print("File content as list:", lines)
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist!")
# Out:
# File content as list: ['Hello, this is a sample text!']

# %% [markdown]
# Q10. How can you append data to an existing file in Python?

# %%
filename = "example.txt"

try:
    with open(filename, "a") as file:
        file.write("This line will be appended.\n")
    print("Data appended successfully.")
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist!")
# Out:
# Data appended successfully.

# %% [markdown]
# Q11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

# %%
my_dict = {"name": "Alice", "age": 25}

try:
    # Attempt to access a key that may not exist
    value = my_dict["address"]
    print("Address:", value)
except KeyError:
    print("Error: The key 'address' does not exist in the dictionary.")
else:
    print("Key accessed successfully.")
# Out:
# Error: The key 'address' does not exist in the dictionary.

# %% [markdown]
# Q12.  Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
    numerator = int(input("Enter numerator: "))
    denominator = int(input("Enter denominator: "))
    result = numerator / denominator
    print("Result:", result)

except ValueError:
    print("Error: Please enter a valid integer.")

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

except Exception as e:
    print("An unexpected error occurred:", e)

else:
    print("Division performed successfully.")

finally:
    print("Execution finished.")
# Out:
# Enter numerator: 12
# Enter denominator: 32
# Result: 0.375
# Division performed successfully.
# Execution finished.

# %% [markdown]
# Q13.  How would you check if a file exists before attempting to read it in Python?

# %%
import os

filename = "example.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"Error: The file '{filename}' does not exist!")
# Out:
# Hello, this is a sample text!This line will be appended.

# %% [markdown]
# Q14. Write a program that uses the logging module to log both informational and error messages.

# %%
import logging


logging.basicConfig(filename="app.log",
                    level=logging.DEBUG,
                    format="%(asctime)s - %(levelname)s - %(message)s")


logging.info("Program started successfully.")

try:
    x = 10
    y = 0
    result = x / y
except ZeroDivisionError as e:
    logging.error("Error occurred: Division by zero.")

logging.info("Program finished execution.")
# Out:
# ERROR:root:Error occurred: Division by zero.

# %% [markdown]
# Q15.  Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
file_name = "example.txt"

try:
    with open(file_name, "r") as file:
        content = file.read()
        if content:
            print("File content:")
            print(content)
        else:
            print("The file is empty.")
except FileNotFoundError:
    print(f"The file '{file_name}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The file 'example.txt' does not exist.

# %% [markdown]
# Q16.  Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
  from memory_profiler import profile

@profile
def create_list():
    my_list = [i for i in range(100000)]
    print("List created.")
    return my_list

@profile
def main():
    data = create_list()
    squared = [x**2 for x in data]
    print("Squared values calculated.")

if __name__ == "__main__":
    main()
# Out:
# ERROR: Could not find file /tmp/ipython-input-3748694344.py
# ERROR: Could not find file /tmp/ipython-input-3748694344.py
# List created.
# Squared values calculated.

# %%
# %pip install memory-profiler
# Out:
# Collecting memory-profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from memory-profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0

# %%
from memory_profiler import profile

@profile
def create_list():
    my_list = [i for i in range(100000)]
    print("List created.")
    return my_list

@profile
def main():
    data = create_list()
    squared = [x**2 for x in data]
    print("Squared values calculated.")

if __name__ == "__main__":
    main()
# Out:
# ERROR: Could not find file /tmp/ipython-input-1391853876.py
# ERROR: Could not find file /tmp/ipython-input-1391853876.py
# List created.
# Squared values calculated.

# %% [markdown]
# Q17.  Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
numbers = [10, 20, 30, 40, 50]

file_name = "numbers.txt"

with open(file_name, "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

print(f"Numbers have been written to '{file_name}'.")
# Out:
# Numbers have been written to 'numbers.txt'.

# %% [markdown]
# Q18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("MyLogger")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler(
    "app.log",
    maxBytes=1*1024*1024,
    backupCount=3
)

formatter = logging.Formatter(
    "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)
handler.setFormatter(formatter)

logger.addHandler(handler)

for i in range(10000):
    logger.info(f"This is log message #{i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:MyLogger:This is log message #5000
# INFO:MyLogger:This is log message #5001
# INFO:MyLogger:This is log message #5002
# INFO:MyLogger:This is log message #5003
# INFO:MyLogger:This is log message #5004
# INFO:MyLogger:This is log message #5005
# INFO:MyLogger:This is log message #5006
# INFO:MyLogger:This is log message #5007
# INFO:MyLogger:This is log message #5008
# INFO:MyLogger:This is log message #5009
# INFO:MyLogger:This is log message #5010
# INFO:MyLogger:This is log message #5011
# INFO:MyLogger:This is log message #5012
# INFO:MyLogger:This is log message #5013
# INFO:MyLogger:This is log message #5014
# INFO:MyLogger:This is log message #5015
# INFO:MyLogger:This is log message #5016
# INFO:MyLogger:This is log message #5017
# INFO:MyLogger:This is log message #5018
# INFO:MyLogger:This is log message #5019
# INFO:MyLogger:This is log message #5020
# INFO:MyLogger:This is log message #5021
# INFO:MyLogger:This is log message #5022
# INFO:MyLogger:This is log message #5023
# INFO:MyLogger:This is log message #5024
# INFO:MyLogger:This is log message #5025
# INFO:MyLogger:This is log message #5026
# INFO:MyLogger:This is log message #5027
# INFO:MyLogger:This is log message #5028
# INFO:MyLogger:This is log message #5029
# INFO:MyLogger:This is log message #5030
# INFO:MyLogger:This is log message #5031
# INFO:MyLogger:This is log message #5032
# INFO:MyLogger:This is log message #5033
# INFO:MyLogger:This is log message #5034
# INFO:MyLogger:This is log message #5035
# INFO:MyLogger:This is log message #5036
# INFO:MyLogger:This is log message #5037
# INFO:MyLogger:This is log message #5038
# INFO:MyLogger:This is log message #5039
# INFO:MyLogger:This is log message #5040
# INFO:MyLogger:This is log message #5041
# INFO:MyLogger:This is log message #5042
# INFO:MyLogger:This is log message #5043
# INFO:MyLogger:This is log message #5044
# INFO:MyLogger:This is log message #5045
# INFO:MyLogger:This is log message #5046
# INFO:MyLogger:This is log message #5047
# INFO:MyLogger:This is log message #5048
# INFO:MyLogger:This is log message #5049
# INFO:MyLogger:This is log message #5050
# INFO:MyLogger:This is log message #5051
# INFO:MyLogger:This is log message #5052
# INFO:MyLogger:This is log message #5053
# INFO:MyLogger:This is log message #5054
# INFO:MyLogger:This is log message #5055
# INFO:MyLogger:This is log message #5056
# INFO:MyLogger:This is log message #5057
# INFO:MyLogger:This is log message #5058
# INFO:MyLogger:This is log message #5059
# INFO:MyLogger:This is log message #5060
# INFO:MyLogger:This is log message #5061
# INFO:MyLogger:This is log message #5062
# INFO:MyLogger:This is log message #5063
# INFO:MyLogger:This is log message #5064
# INFO:MyLogger:This is log message #5065
# INFO:MyLogger:This is log message #5066
# INFO:MyLogger:This is log message #5067
# INFO:MyLogger:This is log message #5068
# INFO:MyLogger:This is log message #5069
# INFO:MyLogger:This is log message #5070
# INFO:MyLogger:This is log message #5071
# INFO:MyLogger:This is log message #5072
# INFO:MyLogger:This is log message #5073
# INFO:MyLogger:This is log message #5074
# INFO:MyLogger:This is log message #5075
# INFO:MyLogger:This is log message #5076
# INFO:MyLogger:This is log message #5077
# INFO:MyLogger:This is log message #5078
# INFO:MyLogger:This is log message #5079
# INFO:MyLogger:This is log message #5080
# INFO:MyLogger:This is log message #5081
# INFO:MyLogger:This is log message #5082
# INFO:MyLogger:This is log message #5083
# INFO:MyLogger:This is log message #5084
# INFO:MyLogger:This is log message #5085
# INFO:MyLogger:This is log message #5086
# INFO:MyLogger:This is log message #5087
# INFO:MyLogger:This is log message #5088
# INFO:MyLogger:This is log message #5089
# INFO:MyLogger:This is log message #5090
# INFO:MyLogger:This is log message #5091
# INFO:MyLogger:This is log message #5092
# INFO:MyLogger:This is log message #5093
# INFO:MyLogger:This is log message #5094
# INFO:MyLogger:This is log message #5095
# INFO:MyLogger:This is log message #5096
# INFO:MyLogger:This is log message #5097
# INFO:MyLogger:This is log message #5098
# INFO:MyLogger:This is log message #5099
# INFO:MyLogger:This is log message #5100
# INFO:MyLogger:This is log message #5101
# INFO:MyLogger:This is log message #5102
# INFO:MyLogger:This is log message #5103
# INFO:MyLogger:This is log message #5104
# INFO:MyLogger:This is log message #5105
# INFO:MyLogger:This is log message #5106
# INFO:MyLogger:This is log message #5107
# INFO:MyLogger:This is log message #5108
# INFO:MyLogger:This is log message #5109
# INFO:MyLogger:This is log message #5110
# INFO:MyLogger:This is log message #5111
# INFO:MyLogger:This is log message #5112
# INFO:MyLogger:This is log message #5113
# INFO:MyLogger:This is log message #5114
# INFO:MyLogger:This is log message #5115
# INFO:MyLogger:This is log message #5116
# INFO:MyLogger:This is log message #5117
# INFO:MyLogger:This is log message #5118
# INFO:MyLogger:This is log message #5119
# INFO:MyLogger:This is log message #5120
# INFO:MyLogger:This is log message #5121
# INFO:MyLogger:This is log message #5122
# INFO:MyLogger:This is log message #5123
# INFO:MyLogger:This is log message #5124
# INFO:MyLogger:This is log message #5125
# INFO:MyLogger:This is log message #5126
# INFO:MyLogger:This is log message #5127
# INFO:MyLogger:This is log message #5128
# INFO:MyLogger:This is log message #5129
# INFO:MyLogger:This is log message #5130
# INFO:MyLogger:This is log message #5131
# INFO:MyLogger:This is log message #5132
# INFO:MyLogger:This is log message #5133
# INFO:MyLogger:This is log message #5134
# INFO:MyLogger:This is log message #5135
# INFO:MyLogger:This is log message #5136
# INFO:MyLogger:This is log message #5137
# INFO:MyLogger:This is log message #5138
# INFO:MyLogger:This is log message #5139
# INFO:MyLogger:This is log message #5140
# INFO:MyLogger:This is log message #5141
# INFO:MyLogger:This is log message #5142
# INFO:MyLogger:This is log message #5143
# INFO:MyLogger:This is log message #5144
# INFO:MyLogger:This is log message #5145
# INFO:MyLogger:This is log message #5146
# INFO:MyLogger:This is log message #5147
# INFO:MyLogger:This is log message #5148
# INFO:MyLogger:This is log message #5149
# INFO:MyLogger:This is log message #5150
# INFO:MyLogger:This is log message #5151
# INFO:MyLogger:This is log message #5152
# INFO:MyLogger:This is log message #5153
# INFO:MyLogger:This is log message #5154
# INFO:MyLogger:This is log message #5155
# INFO:MyLogger:This is log message #5156
# INFO:MyLogger:This is log message #5157
# INFO:MyLogger:This is log message #5158
# INFO:MyLogger:This is log message #5159
# INFO:MyLogger:This is log message #5160
# INFO:MyLogger:This is log message #5161
# INFO:MyLogger:This is log message #5162
# INFO:MyLogger:This is log message #5163
# INFO:MyLogger:This is log message #5164
# INFO:MyLogger:This is log message #5165
# INFO:MyLogger:This is log message #5166
# INFO:MyLogger:This is log message #5167
# INFO:MyLogger:This is log message #5168
# INFO:MyLogger:This is log message #5169
# INFO:MyLogger:This is log message #5170
# INFO:MyLogger:This is log message #5171
# INFO:MyLogger:This is log message #5172
# INFO:MyLogger:This is log message #5173
# INFO:MyLogger:This is log message #5174
# INFO:MyLogger:This is log message #5175
# INFO:MyLogger:This is log message #5176
# INFO:MyLogger:This is log message #5177
# INFO:MyLogger:This is log message #5178
# INFO:MyLogger:This is log message #5179
# INFO:MyLogger:This is log message #5180
# INFO:MyLogger:This is log message #5181
# INFO:MyLogger:This is log message #5182
# INFO:MyLogger:This is log message #5183
# INFO:MyLogger:This is log message #5184
# INFO:MyLogger:This is log message #5185
# INFO:MyLogger:This is log message #5186
# INFO:MyLogger:This is log message #5187
# INFO:MyLogger:This is log message #5188
# INFO:MyLogger:This is log message #5189
# INFO:MyLogger:This is log message #5190
# INFO:MyLogger:This is log message #5191
# INFO:MyLogger:This is log message #5192
# INFO:MyLogger:This is log message #5193
# INFO:MyLogger:This is log message #5194
# INFO:MyLogger:This is log message #5195
# INFO:MyLogger:This is log message #5196
# INFO:MyLogger:This is log message #5197
# INFO:MyLogger:This is log message #5198
# INFO:MyLogger:This is log message #5199
# INFO:MyLogger:This is log message #5200
# INFO:MyLogger:This is log message #5201
# INFO:MyLogger:This is log message #5202
# INFO:MyLogger:This is log message #5203
# INFO:MyLogger:This is log message #5204
# INFO:MyLogger:This is log message #5205
# INFO:MyLogger:This is log message #5206
# INFO:MyLogger:This is log message #5207
# INFO:MyLogger:This is log message #5208
# INFO:MyLogger:This is log message #5209
# INFO:MyLogger:This is log message #5210
# INFO:MyLogger:This is log message #5211
# INFO:MyLogger:This is log message #5212
# INFO:MyLogger:This is log message #5213
# INFO:MyLogger:This is log message #5214
# INFO:MyLogger:This is log message #5215
# INFO:MyLogger:This is log message #5216
# INFO:MyLogger:This is log message #5217
# INFO:MyLogger:This is log message #5218
# INFO:MyLogger:This is log message #5219
# INFO:MyLogger:This is log message #5220
# INFO:MyLogger:This is log message #5221
# INFO:MyLogger:This is log message #5222
# INFO:MyLogger:This is log message #5223
# INFO:MyLogger:This is log message #5224
# INFO:MyLogger:This is log message #5225
# INFO:MyLogger:This is log message #5226
# INFO:MyLogger:This is log message #5227
# INFO:MyLogger:This is log message #5228
# INFO:MyLogger:This is log message #5229
# INFO:MyLogger:This is log message #5230
# INFO:MyLogger:This is log message #5231
# INFO:MyLogger:This is log message #5232
# INFO:MyLogger:This is log message #5233
# INFO:MyLogger:This is log message #5234
# INFO:MyLogger:This is log message #5235
# INFO:MyLogger:This is log message #5236
# INFO:MyLogger:This is log message #5237
# INFO:MyLogger:This is log message #5238
# INFO:MyLogger:This is log message #5239
# INFO:MyLogger:This is log message #5240
# INFO:MyLogger:This is log message #5241
# INFO:MyLogger:This is log message #5242
# INFO:MyLogger:This is log message #5243
# INFO:MyLogger:This is log message #5244
# INFO:MyLogger:This is log message #5245
# INFO:MyLogger:This is log message #5246
# INFO:MyLogger:This is log message #5247
# INFO:MyLogger:This is log message #5248
# INFO:MyLogger:This is log message #5249
# INFO:MyLogger:This is log message #5250
# INFO:MyLogger:This is log message #5251
# INFO:MyLogger:This is log message #5252
# INFO:MyLogger:This is log message #5253
# INFO:MyLogger:This is log message #5254
# INFO:MyLogger:This is log message #5255
# INFO:MyLogger:This is log message #5256
# INFO:MyLogger:This is log message #5257
# INFO:MyLogger:This is log message #5258
# INFO:MyLogger:This is log message #5259
# INFO:MyLogger:This is log message #5260
# INFO:MyLogger:This is log message #5261
# INFO:MyLogger:This is log message #5262
# INFO:MyLogger:This is log message #5263
# INFO:MyLogger:This is log message #5264
# INFO:MyLogger:This is log message #5265
# INFO:MyLogger:This is log message #5266
# INFO:MyLogger:This is log message #5267
# INFO:MyLogger:This is log message #5268
# INFO:MyLogger:This is log message #5269
# INFO:MyLogger:This is log message #5270
# INFO:MyLogger:This is log message #5271
# INFO:MyLogger:This is log message #5272
# INFO:MyLogger:This is log message #5273
# INFO:MyLogger:This is log message #5274
# INFO:MyLogger:This is log message #5275
# INFO:MyLogger:This is log message #5276
# INFO:MyLogger:This is log message #5277
# INFO:MyLogger:This is log message #5278
# INFO:MyLogger:This is log message #5279
# INFO:MyLogger:This is log message #5280
# INFO:MyLogger:This is log message #5281
# INFO:MyLogger:This is log message #5282
# INFO:MyLogger:This is log message #5283
# INFO:MyLogger:This is log message #5284
# INFO:MyLogger:This is log message #5285
# INFO:MyLogger:This is log message #5286
# INFO:MyLogger:This is log message #5287
# INFO:MyLogger:This is log message #5288
# INFO:MyLogger:This is log message #5289
# INFO:MyLogger:This is log message #5290
# INFO:MyLogger:This is log message #5291
# INFO:MyLogger:This is log message #5292
# INFO:MyLogger:This is log message #5293
# INFO:MyLogger:This is log message #5294
# INFO:MyLogger:This is log message #5295
# INFO:MyLogger:This is log message #5296
# INFO:MyLogger:This is log message #5297
# INFO:MyLogger:This is log message #5298
# INFO:MyLogger:This is log message #5299
# INFO:MyLogger:This is log message #5300
# INFO:MyLogger:This is log message #5301
# INFO:MyLogger:This is log message #5302
# INFO:MyLogger:This is log message #5303
# INFO:MyLogger:This is log message #5304
# INFO:MyLogger:This is log message #5305
# INFO:MyLogger:This is log message #5306
# INFO:MyLogger:This is log message #5307
# INFO:MyLogger:This is log message #5308
# INFO:MyLogger:This is log message #5309
# INFO:MyLogger:This is log message #5310
# INFO:MyLogger:This is log message #5311
# INFO:MyLogger:This is log message #5312
# INFO:MyLogger:This is log message #5313
# INFO:MyLogger:This is log message #5314
# INFO:MyLogger:This is log message #5315
# INFO:MyLogger:This is log message #5316
# INFO:MyLogger:This is log message #5317
# INFO:MyLogger:This is log message #5318
# INFO:MyLogger:This is log message #5319
# INFO:MyLogger:This is log message #5320
# INFO:MyLogger:This is log message #5321
# INFO:MyLogger:This is log message #5322
# INFO:MyLogger:This is log message #5323
# INFO:MyLogger:This is log message #5324
# INFO:MyLogger:This is log message #5325
# INFO:MyLogger:This is log message #5326
# INFO:MyLogger:This is log message #5327
# INFO:MyLogger:This is log message #5328
# INFO:MyLogger:This is log message #5329
# INFO:MyLogger:This is log message #5330
# INFO:MyLogger:This is log message #5331
# INFO:MyLogger:This is log message #5332
# INFO:MyLogger:This is log message #5333
# INFO:MyLogger:This is log message #5334
# INFO:MyLogger:This is log message #5335
# INFO:MyLogger:This is log message #5336
# INFO:MyLogger:This is log message #5337
# INFO:MyLogger:This is log message #5338
# INFO:MyLogger:This is log message #5339
# INFO:MyLogger:This is log message #5340
# INFO:MyLogger:This is log message #5341
# INFO:MyLogger:This is log message #5342
# INFO:MyLogger:This is log message #5343
# INFO:MyLogger:This is log message #5344
# INFO:MyLogger:This is log message #5345
# INFO:MyLogger:This is log message #5346
# INFO:MyLogger:This is log message #5347
# INFO:MyLogger:This is log message #5348
# INFO:MyLogger:This is log message #5349
# INFO:MyLogger:This is log message #5350
# INFO:MyLogger:This is log message #5351
# INFO:MyLogger:This is log message #5352
# INFO:MyLogger:This is log message #5353
# INFO:MyLogger:This is log message #5354
# INFO:MyLogger:This is log message #5355
# INFO:MyLogger:This is log message #5356
# INFO:MyLogger:This is log message #5357
# INFO:MyLogger:This is log message #5358
# INFO:MyLogger:This is log message #5359
# INFO:MyLogger:This is log message #5360
# INFO:MyLogger:This is log message #5361
# INFO:MyLogger:This is log message #5362
# INFO:MyLogger:This is log message #5363
# INFO:MyLogger:This is log message #5364
# INFO:MyLogger:This is log message #5365
# INFO:MyLogger:This is log message #5366
# INFO:MyLogger:This is log message #5367
# INFO:MyLogger:This is log message #5368
# INFO:MyLogger:This is log message #5369
# INFO:MyLogger:This is log message #5370
# INFO:MyLogger:This is log message #5371
# INFO:MyLogger:This is log message #5372
# INFO:MyLogger:This is log message #5373
# INFO:MyLogger:This is log message #5374
# INFO:MyLogger:This is log message #5375
# INFO:MyLogger:This is log message #5376
# INFO:MyLogger:This is log message #5377
# INFO:MyLogger:This is log message #5378
# INFO:MyLogger:This is log message #5379
# INFO:MyLogger:This is log message #5380
# INFO:MyLogger:This is log message #5381
# INFO:MyLogger:This is log message #5382
# INFO:MyLogger:This is log message #5383
# INFO:MyLogger:This is log message #5384
# INFO:MyLogger:This is log message #5385
# INFO:MyLogger:This is log message #5386
# INFO:MyLogger:This is log message #5387
# INFO:MyLogger:This is log message #5388
# INFO:MyLogger:This is log message #5389
# INFO:MyLogger:This is log message #5390
# INFO:MyLogger:This is log message #5391
# INFO:MyLogger:This is log message #5392
# INFO:MyLogger:This is log message #5393
# INFO:MyLogger:This is log message #5394
# INFO:MyLogger:This is log message #5395
# INFO:MyLogger:This is log message #5396
# INFO:MyLogger:This is log message #5397
# INFO:MyLogger:This is log message #5398
# INFO:MyLogger:This is log message #5399
# INFO:MyLogger:This is log message #5400
# INFO:MyLogger:This is log message #5401
# INFO:MyLogger:This is log message #5402
# INFO:MyLogger:This is log message #5403
# INFO:MyLogger:This is log message #5404
# INFO:MyLogger:This is log message #5405
# INFO:MyLogger:This is log message #5406
# INFO:MyLogger:This is log message #5407
# INFO:MyLogger:This is log message #5408
# INFO:MyLogger:This is log message #5409
# INFO:MyLogger:This is log message #5410
# INFO:MyLogger:This is log message #5411
# INFO:MyLogger:This is log message #5412
# INFO:MyLogger:This is log message #5413
# INFO:MyLogger:This is log message #5414
# INFO:MyLogger:This is log message #5415
# INFO:MyLogger:This is log message #5416
# INFO:MyLogger:This is log message #5417
# INFO:MyLogger:This is log message #5418
# INFO:MyLogger:This is log message #5419
# INFO:MyLogger:This is log message #5420
# INFO:MyLogger:This is log message #5421
# INFO:MyLogger:This is log message #5422
# INFO:MyLogger:This is log message #5423
# INFO:MyLogger:This is log message #5424
# INFO:MyLogger:This is log message #5425
# INFO:MyLogger:This is log message #5426
# INFO:MyLogger:This is log message #5427
# INFO:MyLogger:This is log message #5428
# INFO:MyLogger:This is log message #5429
# INFO:MyLogger:This is log message #5430
# INFO:MyLogger:This is log message #5431
# INFO:MyLogger:This is log message #5432
# INFO:MyLogger:This is log message #5433
# INFO:MyLogger:This is log message #5434
# INFO:MyLogger:This is log message #5435
# INFO:MyLogger:This is log message #5436
# INFO:MyLogger:This is log message #5437
# INFO:MyLogger:This is log message #5438
# INFO:MyLogger:This is log message #5439
# INFO:MyLogger:This is log message #5440
# INFO:MyLogger:This is log message #5441
# INFO:MyLogger:This is log message #5442
# INFO:MyLogger:This is log message #5443
# INFO:MyLogger:This is log message #5444
# INFO:MyLogger:This is log message #5445
# INFO:MyLogger:This is log message #5446
# INFO:MyLogger:This is log message #5447
# INFO:MyLogger:This is log message #5448
# INFO:MyLogger:This is log message #5449
# INFO:MyLogger:This is log message #5450
# INFO:MyLogger:This is log message #5451
# INFO:MyLogger:This is log message #5452
# INFO:MyLogger:This is log message #5453
# INFO:MyLogger:This is log message #5454
# INFO:MyLogger:This is log message #5455
# INFO:MyLogger:This is log message #5456
# INFO:MyLogger:This is log message #5457
# INFO:MyLogger:This is log message #5458
# INFO:MyLogger:This is log message #5459
# INFO:MyLogger:This is log message #5460
# INFO:MyLogger:This is log message #5461
# INFO:MyLogger:This is log message #5462
# INFO:MyLogger:This is log message #5463
# INFO:MyLogger:This is log message #5464
# INFO:MyLogger:This is log message #5465
# INFO:MyLogger:This is log message #5466
# INFO:MyLogger:This is log message #5467
# INFO:MyLogger:This is log message #5468
# INFO:MyLogger:This is log message #5469
# INFO:MyLogger:This is log message #5470
# INFO:MyLogger:This is log message #5471
# INFO:MyLogger:This is log message #5472
# INFO:MyLogger:This is log message #5473
# INFO:MyLogger:This is log message #5474
# INFO:MyLogger:This is log message #5475
# INFO:MyLogger:This is log message #5476
# INFO:MyLogger:This is log message #5477
# INFO:MyLogger:This is log message #5478
# INFO:MyLogger:This is log message #5479
# INFO:MyLogger:This is log message #5480
# INFO:MyLogger:This is log message #5481
# INFO:MyLogger:This is log message #5482
# INFO:MyLogger:This is log message #5483
# INFO:MyLogger:This is log message #5484
# INFO:MyLogger:This is log message #5485
# INFO:MyLogger:This is log message #5486
# INFO:MyLogger:This is log message #5487
# INFO:MyLogger:This is log message #5488
# INFO:MyLogger:This is log message #5489
# INFO:MyLogger:This is log message #5490
# INFO:MyLogger:This is log message #5491
# INFO:MyLogger:This is log message #5492
# INFO:MyLogger:This is log message #5493
# INFO:MyLogger:This is log message #5494
# INFO:MyLogger:This is log message #5495
# INFO:MyLogger:This is log message #5496
# INFO:MyLogger:This is log message #5497
# INFO:MyLogger:This is log message #5498
# INFO:MyLogger:This is log message #5499
# INFO:MyLogger:This is log message #5500
# INFO:MyLogger:This is log message #5501
# INFO:MyLogger:This is log message #5502
# INFO:MyLogger:This is log message #5503
# INFO:MyLogger:This is log message #5504
# INFO:MyLogger:This is log message #5505
# INFO:MyLogger:This is log message #5506
# INFO:MyLogger:This is log message #5507
# INFO:MyLogger:This is log message #5508
# INFO:MyLogger:This is log message #5509
# INFO:MyLogger:This is log message #5510
# INFO:MyLogger:This is log message #5511
# INFO:MyLogger:This is log message #5512
# INFO:MyLogger:This is log message #5513
# INFO:MyLogger:This is log message #5514
# INFO:MyLogger:This is log message #5515
# INFO:MyLogger:This is log message #5516
# INFO:MyLogger:This is log message #5517
# INFO:MyLogger:This is log message #5518
# INFO:MyLogger:This is log message #5519
# INFO:MyLogger:This is log message #5520
# INFO:MyLogger:This is log message #5521
# INFO:MyLogger:This is log message #5522
# INFO:MyLogger:This is log message #5523
# INFO:MyLogger:This is log message #5524
# INFO:MyLogger:This is log message #5525
# INFO:MyLogger:This is log message #5526
# INFO:MyLogger:This is log message #5527
# INFO:MyLogger:This is log message #5528
# INFO:MyLogger:This is log message #5529
# INFO:MyLogger:This is log message #5530
# INFO:MyLogger:This is log message #5531
# INFO:MyLogger:This is log message #5532
# INFO:MyLogger:This is log message #5533
# INFO:MyLogger:This is log message #5534
# INFO:MyLogger:This is log message #5535
# INFO:MyLogger:This is log message #5536
# INFO:MyLogger:This is log message #5537
# INFO:MyLogger:This is log message #5538
# INFO:MyLogger:This is log message #5539
# INFO:MyLogger:This is log message #5540
# INFO:MyLogger:This is log message #5541
# INFO:MyLogger:This is log message #5542
# INFO:MyLogger:This is log message #5543
# INFO:MyLogger:This is log message #5544
# INFO:MyLogger:This is log message #5545
# INFO:MyLogger:This is log message #5546
# INFO:MyLogger:This is log message #5547
# INFO:MyLogger:This is log message #5548
# INFO:MyLogger:This is log message #5549
# INFO:MyLogger:This is log message #5550
# INFO:MyLogger:This is log message #5551
# INFO:MyLogger:This is log message #5552
# INFO:MyLogger:This is log message #5553
# INFO:MyLogger:This is log message #5554
# INFO:MyLogger:This is log message #5555
# INFO:MyLogger:This is log message #5556
# INFO:MyLogger:This is log message #5557
# INFO:MyLogger:This is log message #5558
# INFO:MyLogger:This is log message #5559
# INFO:MyLogger:This is log message #5560
# INFO:MyLogger:This is log message #5561
# INFO:MyLogger:This is log message #5562
# INFO:MyLogger:This is log message #5563
# INFO:MyLogger:This is log message #5564
# INFO:MyLogger:This is log message #5565
# INFO:MyLogger:This is log message #5566
# INFO:MyLogger:This is log message #5567
# INFO:MyLogger:This is log message #5568
# INFO:MyLogger:This is log message #5569
# INFO:MyLogger:This is log message #5570
# INFO:MyLogger:This is log message #5571
# INFO:MyLogger:This is log message #5572
# INFO:MyLogger:This is log message #5573
# INFO:MyLogger:This is log message #5574
# INFO:MyLogger:This is log message #5575
# INFO:MyLogger:This is log message #5576
# INFO:MyLogger:This is log message #5577
# INFO:MyLogger:This is log message #5578
# INFO:MyLogger:This is log message #5579
# INFO:MyLogger:This is log message #5580
# INFO:MyLogger:This is log message #5581
# INFO:MyLogger:This is log message #5582
# INFO:MyLogger:This is log message #5583
# INFO:MyLogger:This is log message #5584
# INFO:MyLogger:This is log message #5585
# INFO:MyLogger:This is log message #5586
# INFO:MyLogger:This is log message #5587
# INFO:MyLogger:This is log message #5588
# INFO:MyLogger:This is log message #5589
# INFO:MyLogger:This is log message #5590
# INFO:MyLogger:This is log message #5591
# INFO:MyLogger:This is log message #5592
# INFO:MyLogger:This is log message #5593
# INFO:MyLogger:This is log message #5594
# INFO:MyLogger:This is log message #5595
# INFO:MyLogger:This is log message #5596
# INFO:MyLogger:This is log message #5597
# INFO:MyLogger:This is log message #5598
# INFO:MyLogger:This is log message #5599
# INFO:MyLogger:This is log message #5600
# INFO:MyLogger:This is log message #5601
# INFO:MyLogger:This is log message #5602
# INFO:MyLogger:This is log message #5603
# INFO:MyLogger:This is log message #5604
# INFO:MyLogger:This is log message #5605
# INFO:MyLogger:This is log message #5606
# INFO:MyLogger:This is log message #5607
# INFO:MyLogger:This is log message #5608
# INFO:MyLogger:This is log message #5609
# INFO:MyLogger:This is log message #5610
# INFO:MyLogger:This is log message #5611
# INFO:MyLogger:This is log message #5612
# INFO:MyLogger:This is log message #5613
# INFO:MyLogger:This is log message #5614
# INFO:MyLogger:This is log message #5615
# INFO:MyLogger:This is log message #5616
# INFO:MyLogger:This is log message #5617
# INFO:MyLogger:This is log message #5618
# INFO:MyLogger:This is log message #5619
# INFO:MyLogger:This is log message #5620
# INFO:MyLogger:This is log message #5621
# INFO:MyLogger:This is log message #5622
# INFO:MyLogger:This is log message #5623
# INFO:MyLogger:This is log message #5624
# INFO:MyLogger:This is log message #5625
# INFO:MyLogger:This is log message #5626
# INFO:MyLogger:This is log message #5627
# INFO:MyLogger:This is log message #5628
# INFO:MyLogger:This is log message #5629
# INFO:MyLogger:This is log message #5630
# INFO:MyLogger:This is log message #5631
# INFO:MyLogger:This is log message #5632
# INFO:MyLogger:This is log message #5633
# INFO:MyLogger:This is log message #5634
# INFO:MyLogger:This is log message #5635
# INFO:MyLogger:This is log message #5636
# INFO:MyLogger:This is log message #5637
# INFO:MyLogger:This is log message #5638
# INFO:MyLogger:This is log message #5639
# INFO:MyLogger:This is log message #5640
# INFO:MyLogger:This is log message #5641
# INFO:MyLogger:This is log message #5642
# INFO:MyLogger:This is log message #5643
# INFO:MyLogger:This is log message #5644
# INFO:MyLogger:This is log message #5645
# INFO:MyLogger:This is log message #5646
# INFO:MyLogger:This is log message #5647
# INFO:MyLogger:This is log message #5648
# INFO:MyLogger:This is log message #5649
# INFO:MyLogger:This is log message #5650
# INFO:MyLogger:This is log message #5651
# INFO:MyLogger:This is log message #5652
# INFO:MyLogger:This is log message #5653
# INFO:MyLogger:This is log message #5654
# INFO:MyLogger:This is log message #5655
# INFO:MyLogger:This is log message #5656
# INFO:MyLogger:This is log message #5657
# INFO:MyLogger:This is log message #5658
# INFO:MyLogger:This is log message #5659
# INFO:MyLogger:This is log message #5660
# INFO:MyLogger:This is log message #5661
# INFO:MyLogger:This is log message #5662
# INFO:MyLogger:This is log message #5663
# INFO:MyLogger:This is log message #5664
# INFO:MyLogger:This is log message #5665
# INFO:MyLogger:This is log message #5666
# INFO:MyLogger:This is log message #5667
# INFO:MyLogger:This is log message #5668
# INFO:MyLogger:This is log message #5669
# INFO:MyLogger:This is log message #5670
# INFO:MyLogger:This is log message #5671
# INFO:MyLogger:This is log message #5672
# INFO:MyLogger:This is log message #5673
# INFO:MyLogger:This is log message #5674
# INFO:MyLogger:This is log message #5675
# INFO:MyLogger:This is log message #5676
# INFO:MyLogger:This is log message #5677
# INFO:MyLogger:This is log message #5678
# INFO:MyLogger:This is log message #5679
# INFO:MyLogger:This is log message #5680
# INFO:MyLogger:This is log message #5681
# INFO:MyLogger:This is log message #5682
# INFO:MyLogger:This is log message #5683
# INFO:MyLogger:This is log message #5684
# INFO:MyLogger:This is log message #5685
# INFO:MyLogger:This is log message #5686
# INFO:MyLogger:This is log message #5687
# INFO:MyLogger:This is log message #5688
# INFO:MyLogger:This is log message #5689
# INFO:MyLogger:This is log message #5690
# INFO:MyLogger:This is log message #5691
# INFO:MyLogger:This is log message #5692
# INFO:MyLogger:This is log message #5693
# INFO:MyLogger:This is log message #5694
# INFO:MyLogger:This is log message #5695
# INFO:MyLogger:This is log message #5696
# INFO:MyLogger:This is log message #5697
# INFO:MyLogger:This is log message #5698
# INFO:MyLogger:This is log message #5699
# INFO:MyLogger:This is log message #5700
# INFO:MyLogger:This is log message #5701
# INFO:MyLogger:This is log message #5702
# INFO:MyLogger:This is log message #5703
# INFO:MyLogger:This is log message #5704
# INFO:MyLogger:This is log message #5705
# INFO:MyLogger:This is log message #5706
# INFO:MyLogger:This is log message #5707
# INFO:MyLogger:This is log message #5708
# INFO:MyLogger:This is log message #5709
# INFO:MyLogger:This is log message #5710
# INFO:MyLogger:This is log message #5711
# INFO:MyLogger:This is log message #5712
# INFO:MyLogger:This is log message #5713
# INFO:MyLogger:This is log message #5714
# INFO:MyLogger:This is log message #5715
# INFO:MyLogger:This is log message #5716
# INFO:MyLogger:This is log message #5717
# INFO:MyLogger:This is log message #5718
# INFO:MyLogger:This is log message #5719
# INFO:MyLogger:This is log message #5720
# INFO:MyLogger:This is log message #5721
# INFO:MyLogger:This is log message #5722
# INFO:MyLogger:This is log message #5723
# INFO:MyLogger:This is log message #5724
# INFO:MyLogger:This is log message #5725
# INFO:MyLogger:This is log message #5726
# INFO:MyLogger:This is log message #5727
# INFO:MyLogger:This is log message #5728
# INFO:MyLogger:This is log message #5729
# INFO:MyLogger:This is log message #5730
# INFO:MyLogger:This is log message #5731
# INFO:MyLogger:This is log message #5732
# INFO:MyLogger:This is log message #5733
# INFO:MyLogger:This is log message #5734
# INFO:MyLogger:This is log message #5735
# INFO:MyLogger:This is log message #5736
# INFO:MyLogger:This is log message #5737
# INFO:MyLogger:This is log message #5738
# INFO:MyLogger:This is log message #5739
# INFO:MyLogger:This is log message #5740
# INFO:MyLogger:This is log message #5741
# INFO:MyLogger:This is log message #5742
# INFO:MyLogger:This is log message #5743
# INFO:MyLogger:This is log message #5744
# INFO:MyLogger:This is log message #5745
# INFO:MyLogger:This is log message #5746
# INFO:MyLogger:This is log message #5747
# INFO:MyLogger:This is log message #5748
# INFO:MyLogger:This is log message #5749
# INFO:MyLogger:This is log message #5750
# INFO:MyLogger:This is log message #5751
# INFO:MyLogger:This is log message #5752
# INFO:MyLogger:This is log message #5753
# INFO:MyLogger:This is log message #5754
# INFO:MyLogger:This is log message #5755
# INFO:MyLogger:This is log message #5756
# INFO:MyLogger:This is log message #5757
# INFO:MyLogger:This is log message #5758
# INFO:MyLogger:This is log message #5759
# INFO:MyLogger:This is log message #5760
# INFO:MyLogger:This is log message #5761
# INFO:MyLogger:This is log message #5762
# INFO:MyLogger:This is log message #5763
# INFO:MyLogger:This is log message #5764
# INFO:MyLogger:This is log message #5765
# INFO:MyLogger:This is log message #5766
# INFO:MyLogger:This is log message #5767
# INFO:MyLogger:This is log message #5768
# INFO:MyLogger:This is log message #5769
# INFO:MyLogger:This is log message #5770
# INFO:MyLogger:This is log message #5771
# INFO:MyLogger:This is log message #5772
# INFO:MyLogger:This is log message #5773
# INFO:MyLogger:This is log message #5774
# INFO:MyLogger:This is log message #5775
# INFO:MyLogger:This is log message #5776
# INFO:MyLogger:This is log message #5777
# INFO:MyLogger:This is log message #5778
# INFO:MyLogger:This is log message #5779
# INFO:MyLogger:This is log message #5780
# INFO:MyLogger:This is log message #5781
# INFO:MyLogger:This is log message #5782
# INFO:MyLogger:This is log message #5783
# INFO:MyLogger:This is log message #5784
# INFO:MyLogger:This is log message #5785
# INFO:MyLogger:This is log message #5786
# INFO:MyLogger:This is log message #5787
# INFO:MyLogger:This is log message #5788
# INFO:MyLogger:This is log message #5789
# INFO:MyLogger:This is log message #5790
# INFO:MyLogger:This is log message #5791
# INFO:MyLogger:This is log message #5792
# INFO:MyLogger:This is log message #5793
# INFO:MyLogger:This is log message #5794
# INFO:MyLogger:This is log message #5795
# INFO:MyLogger:This is log message #5796
# INFO:MyLogger:This is log message #5797
# INFO:MyLogger:This is log message #5798
# INFO:MyLogger:This is log message #5799
# INFO:MyLogger:This is log message #5800
# INFO:MyLogger:This is log message #5801
# INFO:MyLogger:This is log message #5802
# INFO:MyLogger:This is log message #5803
# INFO:MyLogger:This is log message #5804
# INFO:MyLogger:This is log message #5805
# INFO:MyLogger:This is log message #5806
# INFO:MyLogger:This is log message #5807
# INFO:MyLogger:This is log message #5808
# INFO:MyLogger:This is log message #5809
# INFO:MyLogger:This is log message #5810
# INFO:MyLogger:This is log message #5811
# INFO:MyLogger:This is log message #5812
# INFO:MyLogger:This is log message #5813
# INFO:MyLogger:This is log message #5814
# INFO:MyLogger:This is log message #5815
# INFO:MyLogger:This is log message #5816
# INFO:MyLogger:This is log message #5817
# INFO:MyLogger:This is log message #5818
# INFO:MyLogger:This is log message #5819
# INFO:MyLogger:This is log message #5820
# INFO:MyLogger:This is log message #5821
# INFO:MyLogger:This is log message #5822
# INFO:MyLogger:This is log message #5823
# INFO:MyLogger:This is log message #5824
# INFO:MyLogger:This is log message #5825
# INFO:MyLogger:This is log message #5826
# INFO:MyLogger:This is log message #5827
# INFO:MyLogger:This is log message #5828
# INFO:MyLogger:This is log message #5829
# INFO:MyLogger:This is log message #5830
# INFO:MyLogger:This is log message #5831
# INFO:MyLogger:This is log message #5832
# INFO:MyLogger:This is log message #5833
# INFO:MyLogger:This is log message #5834
# INFO:MyLogger:This is log message #5835
# INFO:MyLogger:This is log message #5836
# INFO:MyLogger:This is log message #5837
# INFO:MyLogger:This is log message #5838
# INFO:MyLogger:This is log message #5839
# INFO:MyLogger:This is log message #5840
# INFO:MyLogger:This is log message #5841
# INFO:MyLogger:This is log message #5842
# INFO:MyLogger:This is log message #5843
# INFO:MyLogger:This is log message #5844
# INFO:MyLogger:This is log message #5845
# INFO:MyLogger:This is log message #5846
# INFO:MyLogger:This is log message #5847
# INFO:MyLogger:This is log message #5848
# INFO:MyLogger:This is log message #5849
# INFO:MyLogger:This is log message #5850
# INFO:MyLogger:This is log message #5851
# INFO:MyLogger:This is log message #5852
# INFO:MyLogger:This is log message #5853
# INFO:MyLogger:This is log message #5854
# INFO:MyLogger:This is log message #5855
# INFO:MyLogger:This is log message #5856
# INFO:MyLogger:This is log message #5857
# INFO:MyLogger:This is log message #5858
# INFO:MyLogger:This is log message #5859
# INFO:MyLogger:This is log message #5860
# INFO:MyLogger:This is log message #5861
# INFO:MyLogger:This is log message #5862
# INFO:MyLogger:This is log message #5863
# INFO:MyLogger:This is log message #5864
# INFO:MyLogger:This is log message #5865
# INFO:MyLogger:This is log message #5866
# INFO:MyLogger:This is log message #5867
# INFO:MyLogger:This is log message #5868
# INFO:MyLogger:This is log message #5869
# INFO:MyLogger:This is log message #5870
# INFO:MyLogger:This is log message #5871
# INFO:MyLogger:This is log message #5872
# INFO:MyLogger:This is log message #5873
# INFO:MyLogger:This is log message #5874
# INFO:MyLogger:This is log message #5875
# INFO:MyLogger:This is log message #5876
# INFO:MyLogger:This is log message #5877
# INFO:MyLogger:This is log message #5878
# INFO:MyLogger:This is log message #5879
# INFO:MyLogger:This is log message #5880
# INFO:MyLogger:This is log message #5881
# INFO:MyLogger:This is log message #5882
# INFO:MyLogger:This is log message #5883
# INFO:MyLogger:This is log message #5884
# INFO:MyLogger:This is log message #5885
# INFO:MyLogger:This is log message #5886
# INFO:MyLogger:This is log message #5887
# INFO:MyLogger:This is log message #5888
# INFO:MyLogger:This is log message #5889
# INFO:MyLogger:This is log message #5890
# INFO:MyLogger:This is log message #5891
# INFO:MyLogger:This is log message #5892
# INFO:MyLogger:This is log message #5893
# INFO:MyLogger:This is log message #5894
# INFO:MyLogger:This is log message #5895
# INFO:MyLogger:This is log message #5896
# INFO:MyLogger:This is log message #5897
# INFO:MyLogger:This is log message #5898
# INFO:MyLogger:This is log message #5899
# INFO:MyLogger:This is log message #5900
# INFO:MyLogger:This is log message #5901
# INFO:MyLogger:This is log message #5902
# INFO:MyLogger:This is log message #5903
# INFO:MyLogger:This is log message #5904
# INFO:MyLogger:This is log message #5905
# INFO:MyLogger:This is log message #5906
# INFO:MyLogger:This is log message #5907
# INFO:MyLogger:This is log message #5908
# INFO:MyLogger:This is log message #5909
# INFO:MyLogger:This is log message #5910
# INFO:MyLogger:This is log message #5911
# INFO:MyLogger:This is log message #5912
# INFO:MyLogger:This is log message #5913
# INFO:MyLogger:This is log message #5914
# INFO:MyLogger:This is log message #5915
# INFO:MyLogger:This is log message #5916
# INFO:MyLogger:This is log message #5917
# INFO:MyLogger:This is log message #5918
# INFO:MyLogger:This is log message #5919
# INFO:MyLogger:This is log message #5920
# INFO:MyLogger:This is log message #5921
# INFO:MyLogger:This is log message #5922
# INFO:MyLogger:This is log message #5923
# INFO:MyLogger:This is log message #5924
# INFO:MyLogger:This is log message #5925
# INFO:MyLogger:This is log message #5926
# INFO:MyLogger:This is log message #5927
# INFO:MyLogger:This is log message #5928
# INFO:MyLogger:This is log message #5929
# INFO:MyLogger:This is log message #5930
# INFO:MyLogger:This is log message #5931
# INFO:MyLogger:This is log message #5932
# INFO:MyLogger:This is log message #5933
# INFO:MyLogger:This is log message #5934
# INFO:MyLogger:This is log message #5935
# INFO:MyLogger:This is log message #5936
# INFO:MyLogger:This is log message #5937
# INFO:MyLogger:This is log message #5938
# INFO:MyLogger:This is log message #5939
# INFO:MyLogger:This is log message #5940
# INFO:MyLogger:This is log message #5941
# INFO:MyLogger:This is log message #5942
# INFO:MyLogger:This is log message #5943
# INFO:MyLogger:This is log message #5944
# INFO:MyLogger:This is log message #5945
# INFO:MyLogger:This is log message #5946
# INFO:MyLogger:This is log message #5947
# INFO:MyLogger:This is log message #5948
# INFO:MyLogger:This is log message #5949
# INFO:MyLogger:This is log message #5950
# INFO:MyLogger:This is log message #5951
# INFO:MyLogger:This is log message #5952
# INFO:MyLogger:This is log message #5953
# INFO:MyLogger:This is log message #5954
# INFO:MyLogger:This is log message #5955
# INFO:MyLogger:This is log message #5956
# INFO:MyLogger:This is log message #5957
# INFO:MyLogger:This is log message #5958
# INFO:MyLogger:This is log message #5959
# INFO:MyLogger:This is log message #5960
# INFO:MyLogger:This is log message #5961
# INFO:MyLogger:This is log message #5962
# INFO:MyLogger:This is log message #5963
# INFO:MyLogger:This is log message #5964
# INFO:MyLogger:This is log message #5965
# INFO:MyLogger:This is log message #5966
# INFO:MyLogger:This is log message #5967
# INFO:MyLogger:This is log message #5968
# INFO:MyLogger:This is log message #5969
# INFO:MyLogger:This is log message #5970
# INFO:MyLogger:This is log message #5971
# INFO:MyLogger:This is log message #5972
# INFO:MyLogger:This is log message #5973
# INFO:MyLogger:This is log message #5974
# INFO:MyLogger:This is log message #5975
# INFO:MyLogger:This is log message #5976
# INFO:MyLogger:This is log message #5977
# INFO:MyLogger:This is log message #5978
# INFO:MyLogger:This is log message #5979
# INFO:MyLogger:This is log message #5980
# INFO:MyLogger:This is log message #5981
# INFO:MyLogger:This is log message #5982
# INFO:MyLogger:This is log message #5983
# INFO:MyLogger:This is log message #5984
# INFO:MyLogger:This is log message #5985
# INFO:MyLogger:This is log message #5986
# INFO:MyLogger:This is log message #5987
# INFO:MyLogger:This is log message #5988
# INFO:MyLogger:This is log message #5989
# INFO:MyLogger:This is log message #5990
# INFO:MyLogger:This is log message #5991
# INFO:MyLogger:This is log message #5992
# INFO:MyLogger:This is log message #5993
# INFO:MyLogger:This is log message #5994
# INFO:MyLogger:This is log message #5995
# INFO:MyLogger:This is log message #5996
# INFO:MyLogger:This is log message #5997
# INFO:MyLogger:This is log message #5998
# INFO:MyLogger:This is log message #5999
# INFO:MyLogger:This is log message #6000
# INFO:MyLogger:This is log message #6001
# INFO:MyLogger:This is log message #6002
# INFO:MyLogger:This is log message #6003
# INFO:MyLogger:This is log message #6004
# INFO:MyLogger:This is log message #6005
# INFO:MyLogger:This is log message #6006
# INFO:MyLogger:This is log message #6007
# INFO:MyLogger:This is log message #6008
# INFO:MyLogger:This is log message #6009
# INFO:MyLogger:This is log message #6010
# INFO:MyLogger:This is log message #6011
# INFO:MyLogger:This is log message #6012
# INFO:MyLogger:This is log message #6013
# INFO:MyLogger:This is log message #6014
# INFO:MyLogger:This is log message #6015
# INFO:MyLogger:This is log message #6016
# INFO:MyLogger:This is log message #6017
# INFO:MyLogger:This is log message #6018
# INFO:MyLogger:This is log message #6019
# INFO:MyLogger:This is log message #6020
# INFO:MyLogger:This is log message #6021
# INFO:MyLogger:This is log message #6022
# INFO:MyLogger:This is log message #6023
# INFO:MyLogger:This is log message #6024
# INFO:MyLogger:This is log message #6025
# INFO:MyLogger:This is log message #6026
# INFO:MyLogger:This is log message #6027
# INFO:MyLogger:This is log message #6028
# INFO:MyLogger:This is log message #6029
# INFO:MyLogger:This is log message #6030
# INFO:MyLogger:This is log message #6031
# INFO:MyLogger:This is log message #6032
# INFO:MyLogger:This is log message #6033
# INFO:MyLogger:This is log message #6034
# INFO:MyLogger:This is log message #6035
# INFO:MyLogger:This is log message #6036
# INFO:MyLogger:This is log message #6037
# INFO:MyLogger:This is log message #6038
# INFO:MyLogger:This is log message #6039
# INFO:MyLogger:This is log message #6040
# INFO:MyLogger:This is log message #6041
# INFO:MyLogger:This is log message #6042
# INFO:MyLogger:This is log message #6043
# INFO:MyLogger:This is log message #6044
# INFO:MyLogger:This is log message #6045
# INFO:MyLogger:This is log message #6046
# INFO:MyLogger:This is log message #6047
# INFO:MyLogger:This is log message #6048
# INFO:MyLogger:This is log message #6049
# INFO:MyLogger:This is log message #6050
# INFO:MyLogger:This is log message #6051
# INFO:MyLogger:This is log message #6052
# INFO:MyLogger:This is log message #6053
# INFO:MyLogger:This is log message #6054
# INFO:MyLogger:This is log message #6055
# INFO:MyLogger:This is log message #6056
# INFO:MyLogger:This is log message #6057
# INFO:MyLogger:This is log message #6058
# INFO:MyLogger:This is log message #6059
# INFO:MyLogger:This is log message #6060
# INFO:MyLogger:This is log message #6061
# INFO:MyLogger:This is log message #6062
# INFO:MyLogger:This is log message #6063
# INFO:MyLogger:This is log message #6064
# INFO:MyLogger:This is log message #6065
# INFO:MyLogger:This is log message #6066
# INFO:MyLogger:This is log message #6067
# INFO:MyLogger:This is log message #6068
# INFO:MyLogger:This is log message #6069
# INFO:MyLogger:This is log message #6070
# INFO:MyLogger:This is log message #6071
# INFO:MyLogger:This is log message #6072
# INFO:MyLogger:This is log message #6073
# INFO:MyLogger:This is log message #6074
# INFO:MyLogger:This is log message #6075
# INFO:MyLogger:This is log message #6076
# INFO:MyLogger:This is log message #6077
# INFO:MyLogger:This is log message #6078
# INFO:MyLogger:This is log message #6079
# INFO:MyLogger:This is log message #6080
# INFO:MyLogger:This is log message #6081
# INFO:MyLogger:This is log message #6082
# INFO:MyLogger:This is log message #6083
# INFO:MyLogger:This is log message #6084
# INFO:MyLogger:This is log message #6085
# INFO:MyLogger:This is log message #6086
# INFO:MyLogger:This is log message #6087
# INFO:MyLogger:This is log message #6088
# INFO:MyLogger:This is log message #6089
# INFO:MyLogger:This is log message #6090
# INFO:MyLogger:This is log message #6091
# INFO:MyLogger:This is log message #6092
# INFO:MyLogger:This is log message #6093
# INFO:MyLogger:This is log message #6094
# INFO:MyLogger:This is log message #6095
# INFO:MyLogger:This is log message #6096
# INFO:MyLogger:This is log message #6097
# INFO:MyLogger:This is log message #6098
# INFO:MyLogger:This is log message #6099
# INFO:MyLogger:This is log message #6100
# INFO:MyLogger:This is log message #6101
# INFO:MyLogger:This is log message #6102
# INFO:MyLogger:This is log message #6103
# INFO:MyLogger:This is log message #6104
# INFO:MyLogger:This is log message #6105
# INFO:MyLogger:This is log message #6106
# INFO:MyLogger:This is log message #6107
# INFO:MyLogger:This is log message #6108
# INFO:MyLogger:This is log message #6109
# INFO:MyLogger:This is log message #6110
# INFO:MyLogger:This is log message #6111
# INFO:MyLogger:This is log message #6112
# INFO:MyLogger:This is log message #6113
# INFO:MyLogger:This is log message #6114
# INFO:MyLogger:This is log message #6115
# INFO:MyLogger:This is log message #6116
# INFO:MyLogger:This is log message #6117
# INFO:MyLogger:This is log message #6118
# INFO:MyLogger:This is log message #6119
# INFO:MyLogger:This is log message #6120
# INFO:MyLogger:This is log message #6121
# INFO:MyLogger:This is log message #6122
# INFO:MyLogger:This is log message #6123
# INFO:MyLogger:This is log message #6124
# INFO:MyLogger:This is log message #6125
# INFO:MyLogger:This is log message #6126
# INFO:MyLogger:This is log message #6127
# INFO:MyLogger:This is log message #6128
# INFO:MyLogger:This is log message #6129
# INFO:MyLogger:This is log message #6130
# INFO:MyLogger:This is log message #6131
# INFO:MyLogger:This is log message #6132
# INFO:MyLogger:This is log message #6133
# INFO:MyLogger:This is log message #6134
# INFO:MyLogger:This is log message #6135
# INFO:MyLogger:This is log message #6136
# INFO:MyLogger:This is log message #6137
# INFO:MyLogger:This is log message #6138
# INFO:MyLogger:This is log message #6139
# INFO:MyLogger:This is log message #6140
# INFO:MyLogger:This is log message #6141
# INFO:MyLogger:This is log message #6142
# INFO:MyLogger:This is log message #6143
# INFO:MyLogger:This is log message #6144
# INFO:MyLogger:This is log message #6145
# INFO:MyLogger:This is log message #6146
# INFO:MyLogger:This is log message #6147
# INFO:MyLogger:This is log message #6148
# INFO:MyLogger:This is log message #6149
# INFO:MyLogger:This is log message #6150
# INFO:MyLogger:This is log message #6151
# INFO:MyLogger:This is log message #6152
# INFO:MyLogger:This is log message #6153
# INFO:MyLogger:This is log message #6154
# INFO:MyLogger:This is log message #6155
# INFO:MyLogger:This is log message #6156
# INFO:MyLogger:This is log message #6157
# INFO:MyLogger:This is log message #6158
# INFO:MyLogger:This is log message #6159
# INFO:MyLogger:This is log message #6160
# INFO:MyLogger:This is log message #6161
# INFO:MyLogger:This is log message #6162
# INFO:MyLogger:This is log message #6163
# INFO:MyLogger:This is log message #6164
# INFO:MyLogger:This is log message #6165
# INFO:MyLogger:This is log message #6166
# INFO:MyLogger:This is log message #6167
# INFO:MyLogger:This is log message #6168
# INFO:MyLogger:This is log message #6169
# INFO:MyLogger:This is log message #6170
# INFO:MyLogger:This is log message #6171
# INFO:MyLogger:This is log message #6172
# INFO:MyLogger:This is log message #6173
# INFO:MyLogger:This is log message #6174
# INFO:MyLogger:This is log message #6175
# INFO:MyLogger:This is log message #6176
# INFO:MyLogger:This is log message #6177
# INFO:MyLogger:This is log message #6178
# INFO:MyLogger:This is log message #6179
# INFO:MyLogger:This is log message #6180
# INFO:MyLogger:This is log message #6181
# INFO:MyLogger:This is log message #6182
# INFO:MyLogger:This is log message #6183
# INFO:MyLogger:This is log message #6184
# INFO:MyLogger:This is log message #6185
# INFO:MyLogger:This is log message #6186
# INFO:MyLogger:This is log message #6187
# INFO:MyLogger:This is log message #6188
# INFO:MyLogger:This is log message #6189
# INFO:MyLogger:This is log message #6190
# INFO:MyLogger:This is log message #6191
# INFO:MyLogger:This is log message #6192
# INFO:MyLogger:This is log message #6193
# INFO:MyLogger:This is log message #6194
# INFO:MyLogger:This is log message #6195
# INFO:MyLogger:This is log message #6196
# INFO:MyLogger:This is log message #6197
# ...
# INFO:MyLogger:This is log message #9600
# INFO:MyLogger:This is log message #9601
# INFO:MyLogger:This is log message #9602
# INFO:MyLogger:This is log message #9603
# INFO:MyLogger:This is log message #9604
# INFO:MyLogger:This is log message #9605
# INFO:MyLogger:This is log message #9606
# INFO:MyLogger:This is log message #9607
# INFO:MyLogger:This is log message #9608
# INFO:MyLogger:This is log message #9609
# INFO:MyLogger:This is log message #9610
# INFO:MyLogger:This is log message #9611
# INFO:MyLogger:This is log message #9612
# INFO:MyLogger:This is log message #9613
# INFO:MyLogger:This is log message #9614
# INFO:MyLogger:This is log message #9615
# INFO:MyLogger:This is log message #9616
# INFO:MyLogger:This is log message #9617
# INFO:MyLogger:This is log message #9618
# INFO:MyLogger:This is log message #9619
# INFO:MyLogger:This is log message #9620
# INFO:MyLogger:This is log message #9621
# INFO:MyLogger:This is log message #9622
# INFO:MyLogger:This is log message #9623
# INFO:MyLogger:This is log message #9624
# INFO:MyLogger:This is log message #9625
# INFO:MyLogger:This is log message #9626
# INFO:MyLogger:This is log message #9627
# INFO:MyLogger:This is log message #9628
# INFO:MyLogger:This is log message #9629
# INFO:MyLogger:This is log message #9630
# INFO:MyLogger:This is log message #9631
# INFO:MyLogger:This is log message #9632
# INFO:MyLogger:This is log message #9633
# INFO:MyLogger:This is log message #9634
# INFO:MyLogger:This is log message #9635
# INFO:MyLogger:This is log message #9636
# INFO:MyLogger:This is log message #9637
# INFO:MyLogger:This is log message #9638
# INFO:MyLogger:This is log message #9639
# INFO:MyLogger:This is log message #9640
# INFO:MyLogger:This is log message #9641
# INFO:MyLogger:This is log message #9642
# INFO:MyLogger:This is log message #9643
# INFO:MyLogger:This is log message #9644
# INFO:MyLogger:This is log message #9645
# INFO:MyLogger:This is log message #9646
# INFO:MyLogger:This is log message #9647
# INFO:MyLogger:This is log message #9648
# INFO:MyLogger:This is log message #9649
# INFO:MyLogger:This is log message #9650
# INFO:MyLogger:This is log message #9651
# INFO:MyLogger:This is log message #9652
# INFO:MyLogger:This is log message #9653
# INFO:MyLogger:This is log message #9654
# INFO:MyLogger:This is log message #9655
# INFO:MyLogger:This is log message #9656
# INFO:MyLogger:This is log message #9657
# INFO:MyLogger:This is log message #9658
# INFO:MyLogger:This is log message #9659
# INFO:MyLogger:This is log message #9660
# INFO:MyLogger:This is log message #9661
# INFO:MyLogger:This is log message #9662
# INFO:MyLogger:This is log message #9663
# INFO:MyLogger:This is log message #9664
# INFO:MyLogger:This is log message #9665
# INFO:MyLogger:This is log message #9666
# INFO:MyLogger:This is log message #9667
# INFO:MyLogger:This is log message #9668
# INFO:MyLogger:This is log message #9669
# INFO:MyLogger:This is log message #9670
# INFO:MyLogger:This is log message #9671
# INFO:MyLogger:This is log message #9672
# INFO:MyLogger:This is log message #9673
# INFO:MyLogger:This is log message #9674
# INFO:MyLogger:This is log message #9675
# INFO:MyLogger:This is log message #9676
# INFO:MyLogger:This is log message #9677
# INFO:MyLogger:This is log message #9678
# INFO:MyLogger:This is log message #9679
# INFO:MyLogger:This is log message #9680
# INFO:MyLogger:This is log message #9681
# INFO:MyLogger:This is log message #9682
# INFO:MyLogger:This is log message #9683
# INFO:MyLogger:This is log message #9684
# INFO:MyLogger:This is log message #9685
# INFO:MyLogger:This is log message #9686
# INFO:MyLogger:This is log message #9687
# INFO:MyLogger:This is log message #9688
# INFO:MyLogger:This is log message #9689
# INFO:MyLogger:This is log message #9690
# INFO:MyLogger:This is log message #9691
# INFO:MyLogger:This is log message #9692
# INFO:MyLogger:This is log message #9693
# INFO:MyLogger:This is log message #9694
# INFO:MyLogger:This is log message #9695
# INFO:MyLogger:This is log message #9696
# INFO:MyLogger:This is log message #9697
# INFO:MyLogger:This is log message #9698
# INFO:MyLogger:This is log message #9699
# INFO:MyLogger:This is log message #9700
# INFO:MyLogger:This is log message #9701
# INFO:MyLogger:This is log message #9702
# INFO:MyLogger:This is log message #9703
# INFO:MyLogger:This is log message #9704
# INFO:MyLogger:This is log message #9705
# INFO:MyLogger:This is log message #9706
# INFO:MyLogger:This is log message #9707
# INFO:MyLogger:This is log message #9708
# INFO:MyLogger:This is log message #9709
# INFO:MyLogger:This is log message #9710
# INFO:MyLogger:This is log message #9711
# INFO:MyLogger:This is log message #9712
# INFO:MyLogger:This is log message #9713
# INFO:MyLogger:This is log message #9714
# INFO:MyLogger:This is log message #9715
# INFO:MyLogger:This is log message #9716
# INFO:MyLogger:This is log message #9717
# INFO:MyLogger:This is log message #9718
# INFO:MyLogger:This is log message #9719
# INFO:MyLogger:This is log message #9720
# INFO:MyLogger:This is log message #9721
# INFO:MyLogger:This is log message #9722
# INFO:MyLogger:This is log message #9723
# INFO:MyLogger:This is log message #9724
# INFO:MyLogger:This is log message #9725
# INFO:MyLogger:This is log message #9726
# INFO:MyLogger:This is log message #9727
# INFO:MyLogger:This is log message #9728
# INFO:MyLogger:This is log message #9729
# INFO:MyLogger:This is log message #9730
# INFO:MyLogger:This is log message #9731
# INFO:MyLogger:This is log message #9732
# INFO:MyLogger:This is log message #9733
# INFO:MyLogger:This is log message #9734
# INFO:MyLogger:This is log message #9735
# INFO:MyLogger:This is log message #9736
# INFO:MyLogger:This is log message #9737
# INFO:MyLogger:This is log message #9738
# INFO:MyLogger:This is log message #9739
# INFO:MyLogger:This is log message #9740
# INFO:MyLogger:This is log message #9741
# INFO:MyLogger:This is log message #9742
# INFO:MyLogger:This is log message #9743
# INFO:MyLogger:This is log message #9744
# INFO:MyLogger:This is log message #9745
# INFO:MyLogger:This is log message #9746
# INFO:MyLogger:This is log message #9747
# INFO:MyLogger:This is log message #9748
# INFO:MyLogger:This is log message #9749
# INFO:MyLogger:This is log message #9750
# INFO:MyLogger:This is log message #9751
# INFO:MyLogger:This is log message #9752
# INFO:MyLogger:This is log message #9753
# INFO:MyLogger:This is log message #9754
# INFO:MyLogger:This is log message #9755
# INFO:MyLogger:This is log message #9756
# INFO:MyLogger:This is log message #9757
# INFO:MyLogger:This is log message #9758
# INFO:MyLogger:This is log message #9759
# INFO:MyLogger:This is log message #9760
# INFO:MyLogger:This is log message #9761
# INFO:MyLogger:This is log message #9762
# INFO:MyLogger:This is log message #9763
# INFO:MyLogger:This is log message #9764
# INFO:MyLogger:This is log message #9765
# INFO:MyLogger:This is log message #9766
# INFO:MyLogger:This is log message #9767
# INFO:MyLogger:This is log message #9768
# INFO:MyLogger:This is log message #9769
# INFO:MyLogger:This is log message #9770
# INFO:MyLogger:This is log message #9771
# INFO:MyLogger:This is log message #9772
# INFO:MyLogger:This is log message #9773
# INFO:MyLogger:This is log message #9774
# INFO:MyLogger:This is log message #9775
# INFO:MyLogger:This is log message #9776
# INFO:MyLogger:This is log message #9777
# INFO:MyLogger:This is log message #9778
# INFO:MyLogger:This is log message #9779
# INFO:MyLogger:This is log message #9780
# INFO:MyLogger:This is log message #9781
# INFO:MyLogger:This is log message #9782
# INFO:MyLogger:This is log message #9783
# INFO:MyLogger:This is log message #9784
# INFO:MyLogger:This is log message #9785
# INFO:MyLogger:This is log message #9786
# INFO:MyLogger:This is log message #9787
# INFO:MyLogger:This is log message #9788
# INFO:MyLogger:This is log message #9789
# INFO:MyLogger:This is log message #9790
# INFO:MyLogger:This is log message #9791
# INFO:MyLogger:This is log message #9792
# INFO:MyLogger:This is log message #9793
# INFO:MyLogger:This is log message #9794
# INFO:MyLogger:This is log message #9795
# INFO:MyLogger:This is log message #9796
# INFO:MyLogger:This is log message #9797
# INFO:MyLogger:This is log message #9798
# INFO:MyLogger:This is log message #9799
# INFO:MyLogger:This is log message #9800
# INFO:MyLogger:This is log message #9801
# INFO:MyLogger:This is log message #9802
# INFO:MyLogger:This is log message #9803
# INFO:MyLogger:This is log message #9804
# INFO:MyLogger:This is log message #9805
# INFO:MyLogger:This is log message #9806
# INFO:MyLogger:This is log message #9807
# INFO:MyLogger:This is log message #9808
# INFO:MyLogger:This is log message #9809
# INFO:MyLogger:This is log message #9810
# INFO:MyLogger:This is log message #9811
# INFO:MyLogger:This is log message #9812
# INFO:MyLogger:This is log message #9813
# INFO:MyLogger:This is log message #9814
# INFO:MyLogger:This is log message #9815
# INFO:MyLogger:This is log message #9816
# INFO:MyLogger:This is log message #9817
# INFO:MyLogger:This is log message #9818
# INFO:MyLogger:This is log message #9819
# INFO:MyLogger:This is log message #9820
# INFO:MyLogger:This is log message #9821
# INFO:MyLogger:This is log message #9822
# INFO:MyLogger:This is log message #9823
# INFO:MyLogger:This is log message #9824
# INFO:MyLogger:This is log message #9825
# INFO:MyLogger:This is log message #9826
# INFO:MyLogger:This is log message #9827
# INFO:MyLogger:This is log message #9828
# INFO:MyLogger:This is log message #9829
# INFO:MyLogger:This is log message #9830
# INFO:MyLogger:This is log message #9831
# INFO:MyLogger:This is log message #9832
# INFO:MyLogger:This is log message #9833
# INFO:MyLogger:This is log message #9834
# INFO:MyLogger:This is log message #9835
# INFO:MyLogger:This is log message #9836
# INFO:MyLogger:This is log message #9837
# INFO:MyLogger:This is log message #9838
# INFO:MyLogger:This is log message #9839
# INFO:MyLogger:This is log message #9840
# INFO:MyLogger:This is log message #9841
# INFO:MyLogger:This is log message #9842
# INFO:MyLogger:This is log message #9843
# INFO:MyLogger:This is log message #9844
# INFO:MyLogger:This is log message #9845
# INFO:MyLogger:This is log message #9846
# INFO:MyLogger:This is log message #9847
# INFO:MyLogger:This is log message #9848
# INFO:MyLogger:This is log message #9849
# INFO:MyLogger:This is log message #9850
# INFO:MyLogger:This is log message #9851
# INFO:MyLogger:This is log message #9852
# INFO:MyLogger:This is log message #9853
# INFO:MyLogger:This is log message #9854
# INFO:MyLogger:This is log message #9855
# INFO:MyLogger:This is log message #9856
# INFO:MyLogger:This is log message #9857
# INFO:MyLogger:This is log message #9858
# INFO:MyLogger:This is log message #9859
# INFO:MyLogger:This is log message #9860
# INFO:MyLogger:This is log message #9861
# INFO:MyLogger:This is log message #9862
# INFO:MyLogger:This is log message #9863
# INFO:MyLogger:This is log message #9864
# INFO:MyLogger:This is log message #9865
# INFO:MyLogger:This is log message #9866
# INFO:MyLogger:This is log message #9867
# INFO:MyLogger:This is log message #9868
# INFO:MyLogger:This is log message #9869
# INFO:MyLogger:This is log message #9870
# INFO:MyLogger:This is log message #9871
# INFO:MyLogger:This is log message #9872
# INFO:MyLogger:This is log message #9873
# INFO:MyLogger:This is log message #9874
# INFO:MyLogger:This is log message #9875
# INFO:MyLogger:This is log message #9876
# INFO:MyLogger:This is log message #9877
# INFO:MyLogger:This is log message #9878
# INFO:MyLogger:This is log message #9879
# INFO:MyLogger:This is log message #9880
# INFO:MyLogger:This is log message #9881
# INFO:MyLogger:This is log message #9882
# INFO:MyLogger:This is log message #9883
# INFO:MyLogger:This is log message #9884
# INFO:MyLogger:This is log message #9885
# INFO:MyLogger:This is log message #9886
# INFO:MyLogger:This is log message #9887
# INFO:MyLogger:This is log message #9888
# INFO:MyLogger:This is log message #9889
# INFO:MyLogger:This is log message #9890
# INFO:MyLogger:This is log message #9891
# INFO:MyLogger:This is log message #9892
# INFO:MyLogger:This is log message #9893
# INFO:MyLogger:This is log message #9894
# INFO:MyLogger:This is log message #9895
# INFO:MyLogger:This is log message #9896
# INFO:MyLogger:This is log message #9897
# INFO:MyLogger:This is log message #9898
# INFO:MyLogger:This is log message #9899
# INFO:MyLogger:This is log message #9900
# INFO:MyLogger:This is log message #9901
# INFO:MyLogger:This is log message #9902
# INFO:MyLogger:This is log message #9903
# INFO:MyLogger:This is log message #9904
# INFO:MyLogger:This is log message #9905
# INFO:MyLogger:This is log message #9906
# INFO:MyLogger:This is log message #9907
# INFO:MyLogger:This is log message #9908
# INFO:MyLogger:This is log message #9909
# INFO:MyLogger:This is log message #9910
# INFO:MyLogger:This is log message #9911
# INFO:MyLogger:This is log message #9912
# INFO:MyLogger:This is log message #9913
# INFO:MyLogger:This is log message #9914
# INFO:MyLogger:This is log message #9915
# INFO:MyLogger:This is log message #9916
# INFO:MyLogger:This is log message #9917
# INFO:MyLogger:This is log message #9918
# INFO:MyLogger:This is log message #9919
# INFO:MyLogger:This is log message #9920
# INFO:MyLogger:This is log message #9921
# INFO:MyLogger:This is log message #9922
# INFO:MyLogger:This is log message #9923
# INFO:MyLogger:This is log message #9924
# INFO:MyLogger:This is log message #9925
# INFO:MyLogger:This is log message #9926
# INFO:MyLogger:This is log message #9927
# INFO:MyLogger:This is log message #9928
# INFO:MyLogger:This is log message #9929
# INFO:MyLogger:This is log message #9930
# INFO:MyLogger:This is log message #9931
# INFO:MyLogger:This is log message #9932
# INFO:MyLogger:This is log message #9933
# INFO:MyLogger:This is log message #9934
# INFO:MyLogger:This is log message #9935
# INFO:MyLogger:This is log message #9936
# INFO:MyLogger:This is log message #9937
# INFO:MyLogger:This is log message #9938
# INFO:MyLogger:This is log message #9939
# INFO:MyLogger:This is log message #9940
# INFO:MyLogger:This is log message #9941
# INFO:MyLogger:This is log message #9942
# INFO:MyLogger:This is log message #9943
# INFO:MyLogger:This is log message #9944
# INFO:MyLogger:This is log message #9945
# INFO:MyLogger:This is log message #9946
# INFO:MyLogger:This is log message #9947
# INFO:MyLogger:This is log message #9948
# INFO:MyLogger:This is log message #9949
# INFO:MyLogger:This is log message #9950
# INFO:MyLogger:This is log message #9951
# INFO:MyLogger:This is log message #9952
# INFO:MyLogger:This is log message #9953
# INFO:MyLogger:This is log message #9954
# INFO:MyLogger:This is log message #9955
# INFO:MyLogger:This is log message #9956
# INFO:MyLogger:This is log message #9957
# INFO:MyLogger:This is log message #9958
# INFO:MyLogger:This is log message #9959
# INFO:MyLogger:This is log message #9960
# INFO:MyLogger:This is log message #9961
# INFO:MyLogger:This is log message #9962
# INFO:MyLogger:This is log message #9963
# INFO:MyLogger:This is log message #9964
# INFO:MyLogger:This is log message #9965
# INFO:MyLogger:This is log message #9966
# INFO:MyLogger:This is log message #9967
# INFO:MyLogger:This is log message #9968
# INFO:MyLogger:This is log message #9969
# INFO:MyLogger:This is log message #9970
# INFO:MyLogger:This is log message #9971
# INFO:MyLogger:This is log message #9972
# INFO:MyLogger:This is log message #9973
# INFO:MyLogger:This is log message #9974
# INFO:MyLogger:This is log message #9975
# INFO:MyLogger:This is log message #9976
# INFO:MyLogger:This is log message #9977
# INFO:MyLogger:This is log message #9978
# INFO:MyLogger:This is log message #9979
# INFO:MyLogger:This is log message #9980
# INFO:MyLogger:This is log message #9981
# INFO:MyLogger:This is log message #9982
# INFO:MyLogger:This is log message #9983
# INFO:MyLogger:This is log message #9984
# INFO:MyLogger:This is log message #9985
# INFO:MyLogger:This is log message #9986
# INFO:MyLogger:This is log message #9987
# INFO:MyLogger:This is log message #9988
# INFO:MyLogger:This is log message #9989
# INFO:MyLogger:This is log message #9990
# INFO:MyLogger:This is log message #9991
# INFO:MyLogger:This is log message #9992
# INFO:MyLogger:This is log message #9993
# INFO:MyLogger:This is log message #9994
# INFO:MyLogger:This is log message #9995
# INFO:MyLogger:This is log message #9996
# INFO:MyLogger:This is log message #9997
# INFO:MyLogger:This is log message #9998
# INFO:MyLogger:This is log message #9999

# %% [markdown]
# Q19.  Write a program that handles both IndexError and KeyError using a try-except block.

# %%
my_list = [10, 20, 30]
my_dict = {"a": 1, "b": 2}

try:
    print("Accessing list index 5:", my_list[5])

    print("Accessing dictionary key 'c':", my_dict["c"])

except IndexError:
    print("Caught an IndexError: List index out of range!")

except KeyError:
    print("Caught a KeyError: Dictionary key does not exist!")

except Exception as e:
    print("Caught some other exception:", e)
# Out:
# Caught an IndexError: List index out of range!

# %% [markdown]
# Q20. How would you open a file and read its contents using a context manager in Python?

# %%
file_name = "example.txt"

with open(file_name, "r") as file:
    content = file.read()

print("File contents:")
print(content)
# Out:
# File contents:
# This is line 1.
# This is line 2.

# %%
file_name = "example.txt"

# Create a dummy file for demonstration
with open(file_name, "w") as file:
    file.write("This is line 1.\n")
    file.write("This is line 2.\n")

print(f"Created '{file_name}' for demonstration.")
# Out:
# Created 'example.txt' for demonstration.

# %% [markdown]
# Q21.  Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
file_name = "example.txt"

word_to_count = "Python"

try:
    with open(file_name, "r") as file:
        content = file.read()

    content_lower = content.lower()
    word_lower = word_to_count.lower()

    count = content_lower.count(word_lower)

    print(f"The word '{word_to_count}' appears {count} times in the file.")

except FileNotFoundError:
    print(f"The file '{file_name}' does not exist.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The file 'example.txt' does not exist.

# %% [markdown]
# Q22. How can you check if a file is empty before attempting to read its contents?

# %%
import os

file_name = "example.txt"

# Check if file exists and is not empty
if os.path.exists(file_name) and os.path.getsize(file_name) > 0:
    with open(file_name, "r") as file:
        content = file.read()
        print("File contents:")
        print(content)
else:
    print(f"The file '{file_name}' is either empty or does not exist.")
# Out:
# The file 'example.txt' is either empty or does not exist.

# %% [markdown]
# Q23.Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

logging.basicConfig(
    filename="file_errors.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

file_name = "example.txt"

try:
    with open(file_name, "r") as file:
        content = file.read()
        print("File content:")
        print(content)

except FileNotFoundError as e:
    print(f"Error: The file '{file_name}' does not exist.")
    logging.error(f"FileNotFoundError: {e}")

except PermissionError as e:
    print(f"Error: Permission denied to read '{file_name}'.")
    logging.error(f"PermissionError: {e}")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
    logging.error(f"Unexpected error: {e}")
# Out:
# ERROR:root:FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'
# Error: The file 'example.txt' does not exist.
